# %% [markdown]
# # <center>Лабораторная Работа № 5.2.2 - 5.2.3</center>
# ## <center>$\mathit{"Изучение~спектров~атома~водорода~и~молекулы~йода"}$</center>
# ###### <center>Выполнил студент группы Б03-903 Деревянкин Иван</center>

# %% [markdown]
# ### 1. Цель работы
# Исследовать спектр поглощения паров йода в видимой области;\
# По результатам измерения вычисляется энергия колебательного кванта молекулы йода и жнергия ее диссоциации в основном и возбужденном состояниях.

# %% [markdown]
# ### 2. В работе используются
#
# <ul>
#     <li>Неоновая лампа;</li>
#     <li>Cпектрометр УМ-2;</li>
#     <li>Ртутная лампа;</li>
#     <li>Водородная лампа;</li>
#     <li>Кювета с йодом;</li>
#     <li>Лампа накаливания;</li>
#     <li>Конденсор;</li>
# </ul>

# %% [markdown]
# ### 3. Теория
#
# ##### Спектр водорода
#
# Атом водорода является простейшей квантовой системой, для которой уравнение Шрёдингера может быть решено точно. Это также верно для водородноподобных атомов, то есть атомов с одним электроном на внешней оболочке. Из решения уравнения Шрёдингера следует, что внешний электрон в таких атомах обладает дискретным энергетическим спектром:
# \begin{equation}
# 	E_n = - \frac{m_e (Z e^2)^2}{2\hbar^2}\frac{1}{n^2},
# \end{equation}
# где $n$ есть номер энергетического уровня, $Z$ есть зарядовое число ядра рассматриваемого атома, которое в случае атома водорода равно 1.\
# При переходе электрона с $n$-го на $m$-й уровень излучается фотон с энергией
# \begin{equation}
# 	E_\gamma = E_n - E_m = \frac{m_ee^2}{2\hbar^2}Z^2\left(\frac{1}{m^2} - \frac{1}{n^2}\right).
# \end{equation}
# Длина волны  соответствующего излучения $\lambda_{n,m}$ связана с номерами уровней следующим соотношением:
# \begin{equation}
# 	\label{eq:Ry}
# 	\lambda_{n,m}^{-1} =\frac{m_ee^2}{4\pi\hbar^3c}Z^2\left(\frac{1}{m^2}-\frac{1}{n^2}\right) = \text{Ry} Z^2 \left(\frac{1}{m^2}-\frac{1}{n^2}\right),
# \end{equation}
# где $\text{Ry} = \frac{m_ee^2}{4\pi\hbar^3c}$ есть постоянная Ридберга.
#
# В данной работе будет исследоваться серия Бальмера атома водорода, в которой электроны совершают переходы с некоторого уровня $n$ на уровень $m = 2$.
#
# <img src="бальмер.png" alt="Рис.1. Схема установки">
#
# #### <center>Рис. 1: Спектральные серии</center>

# %% [markdown]
# ##### Спектр йода
#
# В первом приближении энергия молекулы может быть представлена в виде:
# \begin{equation}
# 	E=E_e+E_o+E_r,
# \end{equation}
# где $E_e$ есть энергия электронных уровней, $E_o$ есть энергия колебательньных уровней, $E_r$ есть энергия вращательных уровней.
#
# В настоящей работе рассматриваются оптические переходы, то есть переходы, связанные с излучением фотонов в видимом диапазоне длин волн. Они соответсвтуют переходам между различными электронными состояниями. При этом также происходят изменения вращательного и колебательного состояний, однако в реальности ввиду малости характерных энергий вращательные переходы ненаблюдаемы.
#
# Более конкретно, изучаются переходы из колебательного состояния с номером $n_1$ освновного электронного уровня с энергией $E_1$ в колебательное состояние с номером $n_2$ на электронный уровень с энергией $E_2$. Энергия таких переходов описывается формулой:
# \begin{equation}
# 	h \nu_{n_1,n_2}=(E_2-E_1)+h\nu_2(n_2+\dfrac{1}{2})-h \nu_1(n_1+\dfrac{1}{2}),
# \end{equation}
# где $\nu_1$ и $\nu_2$ суть энергии колебательных квантов на электронных уровнях с энергиями $E_1$ и $E_2$.
#
# При достаточно больших квантовых числах $n_1$ и $n_2$ колебательные уровни переходят в непрерывный спектр, что соответствует диссоциации молекулы. Наименьшая энергия, которую нужно сообщить молекуле в нижайшем колебательном состоянии, чтобы она диссоциировала, называется энергией диссоциации.
#
# В данной работе определяются энергии диссоциации на первых двух электронных уровнях.

# %% [markdown]
# ### 4. Экспериментальная установка
#
# Для измерения длин волн спектральных линий в работе используется стеклянно-призменный монохроматор-спектрометр УМ-2, предназначенный для спектральных исследований в диапазоне от 0,38 до 1 мкм.
#
# <img src="Схема установки.png" alt="Рис.1. Схема установки">
#
# #### <center>Рис. 1: Схема экспериментальной установки</center>

# %% [markdown]
# В работе осуществляется дополнительная градуировка спектрометра, проводящаяся по спектру ртутной лампы с известными длинами волн спектральных линий.

# %% [markdown]
# ### 5. Выполнение
#
# #### 5.1 Градуировка монохроматора

# %% [markdown]
# ###### Таблица для неона, $\sigma_{\theta} = 1^\circ$

# %%
import numpy as np
import pandas as pd

Theta = [2958, 2931, 2864, 2854, 2824, 2808, 2794, 2758, 2750, 2734, 2722, 2702, 2684, 2664, 2652, 2634, 2622, 2602, 2578, 2564, 2532, 2520, 2256]
Lambda = [7032, 6929, 6717, 6678, 6598, 6532, 6506, 6402, 6382, 6334, 6304, 6266, 6217, 6163, 6143, 6096, 6074, 6030, 5975, 5944, 5881, 5852, 5400]

td = (Theta, Lambda)
tabledata = np.array(td)

pd.DataFrame(tabledata.T, columns=["$\theta, ^{\circ}$", "$\lambda$, A"])
# Out:
#     $\theta, ^{\circ}$  $\lambda$, A
# 0                 2958          7032
# 1                 2931          6929
# 2                 2864          6717
# 3                 2854          6678
# 4                 2824          6598
# 5                 2808          6532
# 6                 2794          6506
# 7                 2758          6402
# 8                 2750          6382
# 9                 2734          6334
# 10                2722          6304
# 11                2702          6266
# 12                2684          6217
# 13                2664          6163
# 14                2652          6143
# 15                2634          6096
# 16                2622          6074
# 17                2602          6030
# 18                2578          5975
# 19                2564          5944
# 20                2532          5881
# 21                2520          5852
# 22                2256          5400

# %% [markdown]
# ###### Таблица для ртути, $\sigma_{\theta} = 1^\circ$

# %%
Theta1 = [2928, 2690, 2486, 2474, 2296, 1872, 1206, 654]
Lambda1 = [6907, 6234, 5791, 5770, 5461, 4916, 4358, 4047]

td1 = (Theta1, Lambda1)
tabledata1 = np.array(td1)

pd.DataFrame(tabledata1.T, columns=["$\theta, ^{\circ}$", "$\lambda$, A"])
# Out:
#    $\theta, ^{\circ}$  $\lambda$, A
# 0                2928          6907
# 1                2690          6234
# 2                2486          5791
# 3                2474          5770
# 4                2296          5461
# 5                1872          4916
# 6                1206          4358
# 7                 654          4047

# %%
from matplotlib import pyplot as plt
from scipy import interpolate
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a + (b/(x - c))

x = Theta
y = Lambda

x1 = Theta1
y1 = Lambda1

TTheta = np.hstack((Theta, Theta1))
LLambda = np.hstack((Lambda, Lambda1))

TTheta = sorted(TTheta)
LLambda = sorted(LLambda)

sigma_x = [1] * 23
sigma_y = [1] * 23

sigma_x1 = [1] * 8
sigma_y1 = [1] * 8

fig = plt.figure(figsize = (14, 12))
ax = fig.add_subplot(111)

ax.set_title(r'Градуировка барабана монохроматора', fontsize = 18)
ax.set_xlabel(r'$\theta, ^{\circ}$', fontsize = 18)
ax.set_ylabel(r'$\lambda, \AA$', fontsize = 18)
ax.errorbar(x, y, sigma_y, sigma_x, marker = 'o', linestyle = 'None', color = 'red', label = 'Неон')
ax.errorbar(x1, y1, sigma_y1, sigma_x1, marker = 'o', linestyle = 'None', color = 'blue', label = 'Ртуть')
p = np.polyfit(TTheta, LLambda, 4)
yp = np.polyval(p, TTheta)
ax.plot(TTheta, yp, marker = 'None', linestyle = '--', color = 'black', label='fit: a=%5.3f, b=%5.3f, c=%5.3f, d=%5.3f, e=%5.3f' % tuple(p))
plt.legend(loc = 'best', fontsize = 18)
ax.minorticks_on()
ax.grid(which='major', color = 'Black', linewidth = 1)
ax.grid(which='minor', color = 'Black', linestyle = ':')


plt.show()

p
# Out:
# array([ 1.28264493e-10, -7.00931441e-07,  1.62507091e-03, -1.04379423e+00,
#         4.20791610e+03])

# %% [markdown]
# Аппроксимиовал полиномом 4-й степени
# Результаты получены в языке Python

# %% [markdown]
# Коэффициенты полинома 4й степени:\
#  a = $(1.283 \pm 0.015)*10^{-10};$\
#  b = $(-7.009 \pm 0.087)*10^{-7};$\
#  c = $(1.625 \pm 0.033)*10^{-3};$\
#  d = $(-1.044 \pm 0.052);$\
#  e = $(4207.916 \pm 220.35)$
#
#  Погрешность посчитана согласно методу наименьших квадратов:
#
# $$
# \sigma_{k}=\frac{1}{\sqrt{n}} \sqrt{\frac{\left\langle V_{\text { }}^{2}\right\rangle}{\left\langle V_{R}^{2}\right\rangle}-k^{2}}
# $$
#
# Погрешность начальных данных не превышает размера маркера на графике.

# %% [markdown]
# #### 5.2 Измерение длин волн линий H и определение постоянной Ридберга

# %% [markdown]
# Определим положения линий $H_{\alpha}, H_{\beta}, H_{\gamma}$ и $H_{\delta}$ с помощью калибровочного графика.
#
# Постоянные Ридберга определим по формуле:
#
# \begin{equation}
#   \dfrac{1}{\lambda_{mn}} = R Z^2 \left( \dfrac{1}{n^2} - \dfrac{1}{m^2} \right)
# \end{equation}
#
# <img src="kek1.png">
#
# #### Результаты и оценка погрешностей:
#
# Среднее значение $R_H$: $R_{\text{ср}} = 10.9 \pm 0.4 \; \text{мкм}^{-1}$
#
# Табличное значение $R_H$: $R_{\text{табл}} = 10.97 \; \text{мкм}^{-1}$
#
# $\lambda = \lambda_0 + \frac{C}{\theta - \theta_0}$, где обозначим $f = \frac{C}{\theta - \theta_0}$
#
# Погрешность длины волны:
#
# $\sigma_{\lambda} = \sqrt{\sigma_{\lambda_0}^2 + \sigma_f^2} $
#
# $\sigma_f = f\sqrt{\frac{\sigma_{\theta}^2 + \sigma_{\theta_0}^2}{(\theta - \theta_0)^2} + \frac{\sigma_C}{C}}$
#
# Погрешность постоянной Ридберга: $\sigma_R = \left( \frac{1}{n^2} - \frac{1}{m^2}\right)^{-1} \frac{1}{Z^2} \left|\frac{\sigma_{\lambda}}{\lambda}\right|$
#
# Погрешность среднего: $\sigma = \sqrt{\frac{1}{n(n-1)}\sum\limits_{i=1}^n (x_i - x_{\text{ср}})^2}$

# %% [markdown]
# #### 5.3 Определение длин волн линий поглощения йода
#
# По значениям барабана определим длины волн линий поглощения.
#
# <img src="kek2.png">
#
# Энергия колебательного кванта возбужденного состояния молекулы йода:
#
# $h\nu_{2} = (h\nu_{1,5} - h\nu_{1,0})/5  \approx 0.0166$ эВ
#
#  С помощью  системы определим энергию электронного перехода, энергию диссоциации в основном и возбужденном состояниях:
#
#
#
# <img src="sys.png">
#
#
# <ol>
#   <li>Энергия электронного перехода:  $ h \nu_{\text{эл}} = 2.00$ эВ.</li>
#   <li>Энергия диссоциации молекулы в основном состоянии: $D_1 = 1.50 $ эВ.</li>
#   <li>Энергия диссоциации молекулы в возбужденном состоянии: $D_2 = 0.45$~эВ.</li>

# %% [markdown]
# ### 6. Вывод
#
# В работе были определены положения линий $H_{\alpha}, H_{\beta}, H_{\gamma}$ и $H_{\delta}$ спектра водорода, из этих данных определена постоянна Ридберга. Среднее значение постоянной $R_{\text{ср}} = 10.9 \pm 0.4 \; \text{мкм}^{-1}$ совпадает с табличным $ R_{\text{табл}} = 10.97 \; \text{мкм}^{-1}$ в пределах $\sigma$. Были рассчитаны энергия колебательного кванта возбужденного состояния молекулы йода, энергии электронного перехода и диссоциаций молекулы в основном и возбужденном состоянии. Значения приведены~в~эВ.

# %% [markdown]
#
# <img src="vyv.png">
