# %%
import matplotlib.pyplot as plt
import numpy as np



x = []
y = []

yerr = [0.0006] * 5 
xerr = [0.00012] * 5

fig = plt.figure(figsize = (16, 9))
ax = fig.add_subplot(111)

ax.errorbar(x, y, yerr, xerr, marker = 'X', linestyle = 'None', color = 'red', label = 'after all')
p = np.polyfit(x, y, 1)
yp = np.polyval(p, x)
ax.plot(x, yp, marker = 'None', color = 'black', label = 'avg')
ax.set_xlabel('1/E')
ax.set_ylabel('R^2')
ax.set_title('Зависимость R^2(1/E)')

print(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-fb1d000c5a9b> in <module>()
#      13 ax = fig.add_subplot(111)
#      14
# ---> 15 ax.errorbar(x, y, yerr, xerr, marker = 'X', linestyle = 'None', color = 'red', label = 'after all')
#      16 p = np.polyfit(x, y, 1)
#      17 yp = np.polyval(p, x)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3326
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np



x = [735, 1599, 929]
y = [511, 1173, 661]

yerr = [0] * 3
xerr = [9] * 3

fig = plt.figure(figsize = (12, 7))
ax = fig.add_subplot(111)

ax.errorbar(x, y, yerr, xerr, marker = 'X', linestyle = 'None', color = 'red', label = 'after all')
p = np.polyfit(x, y, 1)
yp = np.polyval(p, x)
ax.plot(x, yp, marker = 'None',  color = 'black', label = 'avg')
ax.set_xlabel('Номер канал')
ax.set_ylabel('Энергия, кэВ')
ax.set_title('Калибровочный график')


print(p)

fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(111)

ax.set_title('Калибровочный график', fontsize = 18)
ax.set_xlabel('Номер канал', fontsize = 18)
ax.set_ylabel('Энергия, кэВ', fontsize = 18)
ax.errorbar(x, y, yerr, xerr, marker = 'X', linestyle = 'None', color = 'red', label = 'Error')
p = np.polyfit(x, y, 1)
yp = np.polyval(p, x)
ax.plot(x, yp, marker = 'None', linestyle = '-', color = 'black', label = 'Fitting')
plt.legend(loc = 'best', fontsize = 18)
ax.minorticks_on()
ax.grid(which='major', color = 'orange', linewidth = 1)
ax.grid(which='minor', color = 'orange', linestyle = ':')

plt.show()
# Out:
# [  0.76568005 -51.13799804]

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 100     # число экспериментов
sigma = 3   # стандартное отклонение наблюдаемых значений
k = 0.5     # теоретическое значение параметра k
b = 2       # теоретическое значение параметра b

x = np.array(range(N))
f = np.array([k*z+b for z in range(N)])
y = f + np.random.normal(0, sigma, N)

# вычисляем коэффициенты
mx = x.sum()/N
my = y.sum()/N
a2 = np.dot(x.T, x)/N
a11 = np.dot(x.T, y)/N

kk = (a11 - mx*my)/(a2 - mx**2)
bb = my - kk*mx
ff = np.array([kk*z+bb for z in range(N)])

plt.scatter(x, y, s=2, c='red')
plt.plot(f)
plt.plot(ff, c='red')
plt.grid(True)
plt.show()

fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(111)

p = np.polyfit(x, y, 1)
yp = np.polyval(p, x)
.scatter(x, y, s=2, c='red')
ax.plot(x, yp, marker = 'None', linestyle = '-', color = 'black', label = 'Fitting')
plt.legend(loc = 'best', fontsize = 18)
ax.minorticks_on()
ax.grid(which='major', color = 'orange', linewidth = 1)
ax.grid(which='minor', color = 'orange', linestyle = ':')

plt.show()
